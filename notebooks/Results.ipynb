# %%
import pandas as pd

# %% [markdown]
# ### error_metric_logistic_regression_with_feature_selection

# %%
data = pd.read_csv('../data/results/error_metric_logistic_regression_with_feature_selection_2024-01-30.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data['metrics']=['accuracy','F1','reacall','precission','kappa']
data = data.set_index('metrics')
data
# Out:
#                Train      Test       Val
# metrics
# accuracy    0.858871  0.805643  0.753703
# F1          0.865729  0.813814  0.771035
# reacall     0.876375  0.822458  0.781799
# precission  0.855338  0.805349  0.760563
# kappa       0.717050  0.610582  0.504676

# %% [markdown]
# ### error_metric_logistic_regression_without_feature_selection

# %%
data = pd.read_csv('../data/results/error_metric_logistic_regression_without_feature_selection_2024-01-30.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data['metrics']=['accuracy','F1','reacall','precission','kappa']
data = data.set_index('metrics')
data
# Out:
#                Train      Test       Val
# metrics
# accuracy    0.861895  0.789969  0.741086
# F1          0.868227  0.811533  0.784672
# reacall     0.876375  0.875569  0.889349
# precission  0.860229  0.756225  0.702041
# kappa       0.723177  0.577211  0.471096

# %% [markdown]
# ### error_metric_random_forest_with_feature_selection_with_GridSearch

# %%
data = pd.read_csv('../data/results/error_metric_random_forest_with_feature_selection_with_GridSearch_2024-01-30.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data['metrics']=['accuracy','F1','reacall','precission','kappa']
data = data.set_index('metrics')
data
# Out:
#                Train      Test       Val
# metrics
# accuracy    0.935820  0.804075  0.755348
# F1          0.938841  0.815089  0.775654
# reacall     0.948867  0.836115  0.797311
# precission  0.929024  0.795094  0.755142
# kappa       0.871342  0.607035  0.507091

# %% [markdown]
# ### error_metric_random_forest_with_feature_selection_without_GridSearch

# %%
data = pd.read_csv('../data/results/error_metric_random_forest_with_feature_selection_without_GridSearch_2024-01-30.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data['metrics']=['accuracy','F1','reacall','precission','kappa']
data = data.set_index('metrics')
data
# Out:
#             Train      Test       Val
# metrics
# accuracy      1.0  0.807994  0.753154
# F1            1.0  0.817844  0.771109
# reacall       1.0  0.834598  0.783868
# precission    1.0  0.801749  0.758759
# kappa         1.0  0.615034  0.503406

# %% [markdown]
# ### error_metric_random_forest_without_feature_selection_with_GridSearch

# %%
data = pd.read_csv('../data/results/error_metric_random_forest_without_feature_selection_with_GridSearch_2024-01-30.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data['metrics']=['accuracy','F1','reacall','precission','kappa']
data = data.set_index('metrics')
data
# Out:
#                Train      Test       Val
# metrics
# accuracy    0.883065  0.796238  0.736149
# F1          0.890152  0.815341  0.768416
# reacall     0.912621  0.871017  0.825233
# precission  0.868762  0.766355  0.718919
# kappa       0.765313  0.590129  0.465207

# %% [markdown]
# ### error_metric_random_forest_without_feature_selection_without_GridSearch

# %%
data = pd.read_csv('../data/results/error_metric_random_forest_without_feature_selection_without_GridSearch_2024-01-30.csv')
data.drop('Unnamed: 0', axis=1, inplace=True)
data['metrics']=['accuracy','F1','reacall','precission','kappa']
data = data.set_index('metrics')
data
# Out:
#             Train      Test       Val
# metrics
# accuracy      1.0  0.793103  0.734504
# F1            1.0  0.807018  0.762512
# reacall       1.0  0.837633  0.803516
# precission    1.0  0.778561  0.725490
# kappa         1.0  0.584686  0.463289
